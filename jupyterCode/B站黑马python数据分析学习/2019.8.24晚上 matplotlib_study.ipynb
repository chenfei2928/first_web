# %% [markdown]
# 本问主要记录了2.1-2.4章节的学习记录
#
# 主要学习内容包括：
#     1、显示图表 plt.plot(x,y)
#         保存图片 plt.savefig('文件名.=')
#     2、设置图片大小，像素大小,fig=figure(figsize=(20,8),dpi=100)
#     3、设置x轴，y轴刻度，
#     4、刻度中文显示，刻度方向
#
# https://www.cnblogs.com/pacino12134/p/9776882.html  中文字体设置参考网页

# %%
import matplotlib.pyplot as plt

x = range(2,26,2)

y = [15,14,16,18,20,35,45,23,12,19,20,30]

# fig 属性在plt.调用前定义即可生效。

# 设置画布大小
fig = plt.figure(figsize =(20,8),  #设置图片大小
                 dpi =100)         #设置像素



# 绘图
plt.plot(x,y)


# 设置x轴刻度

#plt.xticks(range(x)

#plt.xticks(range(2,25,0.5))

_xtick_labels = [i/2 for i in range(4,49)]
plt.xticks(_xtick_labels[::3])



# 设置y轴刻度
#plt.yticks(y)

plt.yticks(range(min(y),max(y)+1))


# 保存

#plt.savefig("t1.png")

# 展示图形
plt.show()

# %% [markdown]
# 问题
#   a表示10点到12点的每一分钟气温，如何绘制折线图观察气温变化
#   a = [random.randint(20,35) for i in range(120)]

# %%
import random

x = range(0,120)
y = [random.randint(20,35) for i in range(120)]

fig = plt.figure(figsize = (20,8))  # 设置图片大小

plt.plot(x,y)


plt.show()

# %%
import random


#import matplotlib
#font = {'family':'MicroSoft YaHei',
#        'weight':'bold',
#        'size':'larger'}

#matplotlib.rc("font",**font)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 解决matplotlib中 中文不显示问题；


x = range(0,120)
y = [random.randint(20,35) for i in range(120)]

fig = plt.figure(figsize = (20,8))  # 设置图片大小

plt.plot(x,y)

_xtick_labels = ["10点{}分".format(i) for i in range(60)]
_xtick_labels += ["11点{}分".format(i) for i in range(60)]

plt.xticks(list(x)[::3],_xtick_labels[::3],
          rotation=45)



plt.show()


# list后可以取步长，

# %%
import random


#import matplotlib
#font = {'family':'MicroSoft YaHei',
#        'weight':'bold',
#        'size':'larger'}

#matplotlib.rc("font",**font)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 解决matplotlib中 中文不显示问题；


x = range(0,120)
y = [random.randint(20,35) for i in range(120)]

fig = plt.figure(figsize = (20,8))  # 设置画布大小

plt.plot(x,y)

_xtick_labels = ["10点{}分".format(i) for i in range(60)]
_xtick_labels += ["11点{}分".format(i) for i in range(60)]

plt.xticks(list(x)[::3],_xtick_labels[::3],
          rotation=45)

# 添加描述信息

plt.xlabel('时间')
plt.ylabel('温度℃')
plt.title('10点到12点每分钟温度变化情况')
plt.show()


# list后可以取步长，

# %%
help(plt.rcParams)
# Out:
# Help on RcParams in module matplotlib object:
#
# class RcParams(collections.abc.MutableMapping, builtins.dict)
#  |  RcParams(*args, **kwargs)
#  |
#  |  A dictionary object including validation
#  |
#  |  validating functions are defined and associated with rc parameters in
#  |  :mod:`matplotlib.rcsetup`
#  |
#  |  Method resolution order:
#  |      RcParams
#  |      collections.abc.MutableMapping
#  |      collections.abc.Mapping
#  |      collections.abc.Collection
#  |      collections.abc.Sized
#  |      collections.abc.Iterable
#  |      collections.abc.Container
#  |      builtins.dict
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, key)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Yield sorted list of keys.
#  |
#  |  __len__(self)
#  |      Return len(self).
#  |
#  |  __repr__(self)
# ...
