# %%
import pandas as pd
data = pd.read_csv('C:/Users/Administrator/Desktop/python/cars.csv')
data
# Out:
#      Unnamed: 0  symboling normalized-losses           make fuel-type  \
# 0            49          0                 ?         jaguar       gas
# 1            73          0                 ?  mercedes-benz       gas
# 2            74          1                 ?  mercedes-benz       gas
# 3            17          0                 ?            bmw       gas
# 4            47          0               145         jaguar       gas
# 5            48          0                 ?         jaguar       gas
# 6             9          0                 ?           audi       gas
# 7            15          0                 ?            bmw       gas
# 8            16          0                 ?            bmw       gas
# 9            58          3               150          mazda       gas
# 10           71         -1                 ?  mercedes-benz       gas
# 11           72          3               142  mercedes-benz       gas
# 12            8          1               158           audi       gas
# 13           55          3               150          mazda       gas
# 14           56          3               150          mazda       gas
# 15           57          3               150          mazda       gas
# 16          101          0               128         nissan       gas
# 17          102          0               108         nissan       gas
# 18          105          3               194         nissan       gas
# 19          126          3                 ?        porsche       gas
# 20          127          3                 ?        porsche       gas
# 21          128          3                 ?        porsche       gas
# 22          129          1                 ?        porsche       gas
# 23          198         -2               103          volvo       gas
# 24          199         -1                74          volvo       gas
# 25            4          2               164           audi       gas
# 26          117          0               161         peugot       gas
# 27          202         -1                95          volvo       gas
# 28            2          1                 ?    alfa-romero       gas
# 29            5          2                 ?           audi       gas
# ..          ...        ...               ...            ...       ...
# 175          97          1               103         nissan       gas
# 176          98          2               168         nissan       gas
# 177         120          1               154       plymouth       gas
# 178         121          1               154       plymouth       gas
# 179         122          1               154       plymouth       gas
# 180         138          2                83         subaru       gas
# 181         151          1                87         toyota       gas
# 182         152          1                74         toyota       gas
# 183         153          0                77         toyota       gas
# 184         141          0               102         subaru       gas
# 185         192          0                 ?     volkswagen    diesel
# 186         158          0                91         toyota    diesel
# 187         150          1                87         toyota       gas
# 188          63          0                 ?          mazda    diesel
# 189          21          1               118          dodge       gas
# 190          76          2               161     mitsubishi       gas
# 191         118          1               119       plymouth       gas
# 192         182          2               122     volkswagen    diesel
# 193         184          2                94     volkswagen    diesel
# 194         187          2                94     volkswagen    diesel
# 195          19          1                98      chevrolet       gas
# 196          20          0                81      chevrolet       gas
# 197          32          1               101          honda       gas
# 198          44          1                 ?          isuzu       gas
# 199          45          0                 ?          isuzu       gas
# 200         159          0                91         toyota    diesel
# 201         160          0                91         toyota       gas
# 202          90          1               128         nissan    diesel
# 203          18          2               121      chevrolet       gas
# 204          30          2               137          honda       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# 0          std          two        sedan          rwd           front  ...
# 1          std         four        sedan          rwd           front  ...
# 2          std          two      hardtop          rwd           front  ...
# 3          std         four        sedan          rwd           front  ...
# 4          std         four        sedan          rwd           front  ...
# 5          std         four        sedan          rwd           front  ...
# 6        turbo          two    hatchback          4wd           front  ...
# 7          std         four        sedan          rwd           front  ...
# 8          std          two        sedan          rwd           front  ...
# 9          std          two    hatchback          rwd           front  ...
# 10         std         four        sedan          rwd           front  ...
# 11         std          two  convertible          rwd           front  ...
# 12       turbo         four        sedan          fwd           front  ...
# 13         std          two    hatchback          rwd           front  ...
# 14         std          two    hatchback          rwd           front  ...
# 15         std          two    hatchback          rwd           front  ...
# 16         std         four        sedan          fwd           front  ...
# 17         std         four        wagon          fwd           front  ...
# 18       turbo          two    hatchback          rwd           front  ...
# 19         std          two      hardtop          rwd            rear  ...
# 20         std          two      hardtop          rwd            rear  ...
# 21         std          two  convertible          rwd            rear  ...
# 22         std          two    hatchback          rwd           front  ...
# 23       turbo         four        sedan          rwd           front  ...
# 24       turbo         four        wagon          rwd           front  ...
# 25         std         four        sedan          4wd           front  ...
# 26       turbo         four        sedan          rwd           front  ...
# 27         std         four        sedan          rwd           front  ...
# 28         std          two    hatchback          rwd           front  ...
# 29         std          two        sedan          fwd           front  ...
# ..         ...          ...          ...          ...             ...  ...
# 175        std         four        wagon          fwd           front  ...
# 176        std          two      hardtop          fwd           front  ...
# 177        std         four    hatchback          fwd           front  ...
# 178        std         four        sedan          fwd           front  ...
# 179        std         four        sedan          fwd           front  ...
# 180        std          two    hatchback          fwd           front  ...
# 181        std          two    hatchback          fwd           front  ...
# 182        std         four    hatchback          fwd           front  ...
# 183        std         four        wagon          fwd           front  ...
# 184        std         four        sedan          fwd           front  ...
# 185      turbo         four        sedan          fwd           front  ...
# 186        std         four        sedan          fwd           front  ...
# 187        std          two    hatchback          fwd           front  ...
# 188        std         four        sedan          fwd           front  ...
# 189        std          two    hatchback          fwd           front  ...
# 190        std          two    hatchback          fwd           front  ...
# 191        std          two    hatchback          fwd           front  ...
# 192        std          two        sedan          fwd           front  ...
# 193        std         four        sedan          fwd           front  ...
# 194      turbo         four        sedan          fwd           front  ...
# 195        std          two    hatchback          fwd           front  ...
# 196        std         four        sedan          fwd           front  ...
# 197        std          two    hatchback          fwd           front  ...
# 198        std          two        sedan          fwd           front  ...
# 199        std         four        sedan          fwd           front  ...
# 200        std         four    hatchback          fwd           front  ...
# 201        std         four        sedan          fwd           front  ...
# 202        std          two        sedan          fwd           front  ...
# 203        std          two    hatchback          fwd           front  ...
# 204        std          two    hatchback          fwd           front  ...
#
#      engine-size  fuel-system  bore  stroke  compression-ratio horsepower  \
# 0            326         mpfi  3.54    2.76              11.50      262.0
# 1            308         mpfi   3.8    3.35               8.00      184.0
# 2            304         mpfi   3.8    3.35               8.00      184.0
# 3            209         mpfi  3.62    3.39               8.00      182.0
# 4            258         mpfi  3.63    4.17               8.10      176.0
# 5            258         mpfi  3.63    4.17               8.10      176.0
# 6            131         mpfi  3.13    3.40               7.00      160.0
# 7            209         mpfi  3.62    3.39               8.00      182.0
# 8            209         mpfi  3.62    3.39               8.00      182.0
# 9             80         mpfi     ?    2.00               9.40      135.0
# 10           234         mpfi  3.46    3.10               8.30      155.0
# 11           234         mpfi  3.46    3.10               8.30      155.0
# 12           131         mpfi  3.13    3.40               8.30      140.0
# 13            70         4bbl     ?    2.00               9.40      101.0
# 14            70         4bbl     ?    2.00               9.40      101.0
# 15            70         4bbl     ?    2.00               9.40      101.0
# 16           181         mpfi  3.43    3.27               9.00      152.0
# 17           181         mpfi  3.43    3.27               9.00      152.0
# 21    5900.0        17          25  37028.0
# 22    5750.0        17          28      NaN
# 23    5100.0        17          22  18420.0
# 24    5100.0        17          22  18950.0
# 25    5500.0        18          22  17450.0
# 26    5600.0        18          24  18150.0
# 27    5500.0        18          23  21485.0
# 28    5000.0        19          26  16500.0
# 29    5500.0        19          25  15250.0
# ..       ...       ...         ...      ...
# 175   5200.0        31          37   7999.0
# 176   5200.0        31          37   8249.0
# 177   5500.0        31          38   6229.0
# 178   5500.0        31          38   6692.0
# 179   5500.0        31          38   7609.0
# 180   4900.0        31          36   5118.0
# 181   4800.0        31          38   6338.0
# 182   4800.0        31          38   6488.0
# 183   4800.0        31          37   6918.0
# 184   4800.0        32          37   7126.0
# 185   4500.0        33          38  13845.0
# 186   4500.0        34          36   7898.0
# 187   4800.0        35          39   5348.0
# 188   4650.0        36          42  10795.0
# 189   5500.0        37          41   5572.0
# 190   5500.0        37          41   5389.0
# 191   5500.0        37          41   5572.0
# 192   4800.0        37          46   7775.0
# 193   4800.0        37          46   7995.0
# 194   4500.0        37          42   9495.0
# 195   5400.0        38          43   6295.0
# 196   5400.0        38          43   6575.0
# 197   5500.0        38          42   5399.0
# 198   5400.0        38          43      NaN
# 199   5400.0        38          43      NaN
# 200   4500.0        38          47   7788.0
# 201   4800.0        38          47   7738.0
# 202   4800.0        45          50   7099.0
# 203   5100.0        47          53   5151.0
# 204   4800.0        49          54   6479.0
#
# [205 rows x 27 columns]

# %% [markdown]
# plotly介绍
# matplotlib是Python中最广为人知的图表绘制框架。但是它实在太复杂了，如果要画出较为漂亮的图，则需要付出很多的时间与精力。这次介绍一个Python下能轻松生成各种图表的框架plotly plotly是一个可交互，基于浏览器的绘图库，主打功能是绘制在线可交互的图表,所绘制出来的图表真的赏心悦目。它所支持的语言不只是Python，还支持诸如r,matlab,javescript等语言。plotly绘制的图能直接在jupyter中查看，也能保存为离线网页，或者保存在plot.ly云端服务器内，以便在线查看。
#
# 如果使用Python语言，建议用jupyter notebook或jupyterlab作为IDE， 在pycharm中使用plotly并不是一种很好的体验。

# %%
#绘制 2D图
import plotly
import plotly.graph_objs as go

# 绘制散点图

fig1 = go.Scatter(x=data['curb-weight'],
                 y=data['price'],
                 mode = 'markers')

# 绘制布局
mylayout = go.Layout(xaxis=dict(title='curb-weight'),
                    yaxis=dict(title='price'))

# 绘制html

plotly.offline.plot({'data':[fig1],'layout':mylayout},
                   auto_open=True)
# Out:
# 'temp-plot.html'

# %%
# 绘制3D图

fig1 = go.Scatter3d(x=data['curb-weight'],
                   y=data['horsepower'],
                   z=data['price'],
                   marker=dict(opacity=0.9,
                               reversescale=True,
                               colorscale='Blues',
                               size=5),
                    line=dict(width=0.02),
                    mode='markers'
                   )

mylayout = go.Layout(scene = dict(xaxis=dict(title='curb-weight'),
                                 yaxis=dict(title='horsepower'),
                                 zaxis=dict(title='price')),
                    )

plotly.offline.plot({'data':[fig1],
                    'layout':mylayout},
                    auto_open=True,
                    filename=('3DPlot.html')    
                    )
# Out:
# '3DPlot.html'

# %%
# 绘制4D图

# 无代码，不做了
